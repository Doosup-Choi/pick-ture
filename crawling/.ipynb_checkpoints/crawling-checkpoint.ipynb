# %%
import requests
import urllib

# %%
query = "그림" #검색을 원하는 문자열
display = "20" #기본10 최대1000
start = "1" #최소1 최대1000
sort = "date" #정렬 옵션 : sim(유사도), date(날짜순), asc(가격오름차순), dsc(가격내림차순)

query = urllib.parse.quote(query)

url = "https://openapi.naver.com/v1/search/shop?query=" + query + "&display=" + display+ "&start=" + start + "&sort=" + sort 

client_id = "ns_lsVeiLXPoagHNyqXD"
client_secret = "tKVxt4TFYp"

request = urllib.request.Request(url)
request.add_header('X-Naver-Client-Id', client_id)
request.add_header('X-Naver-Client-Secret', client_secret)

response = urllib.request.urlopen(request)
print(response.read().decode('utf-8'))
# Out:
# {
# "lastBuildDate": "Sun, 21 Nov 2021 20:18:55 +0900",
# "total": 9821744,
# "start": 1,
# "display": 20,
# "items": [
# {
# "title": "인메이블 앙리 마티스 드로잉105종 캔버스액자 명화<b>그림</b>",
# "link": "https://search.shopping.naver.com/gate.nhn?id=29065488909",
# "image": "https://shopping-phinf.pstatic.net/main_2906548/29065488909.20211001224714.jpg",
# "lprice": "2500",
# "hprice": "",
# "mallName": "네이버",
# "productId": "29065488909",
# "productType": "1",
# "brand": "",
# "maker": "",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "인테리어액자 미드 센츄리 모던 <b>그림</b> 사진",
# "link": "https://search.shopping.naver.com/gate.nhn?id=28890835541",
# "image": "https://shopping-phinf.pstatic.net/main_2889083/28890835541.20210917200238.jpg",
# "lprice": "2900",
# "hprice": "",
# "mallName": "네이버",
# "productId": "28890835541",
# "productType": "1",
# "brand": "",
# "maker": "",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "명화그리기 DIY 유화그리기세트 액자 <b>그림</b> 팝아트",
# "link": "https://search.shopping.naver.com/gate.nhn?id=10710795782",
# "image": "https://shopping-phinf.pstatic.net/main_1071079/10710795782.3.jpg",
# "lprice": "4400",
# "hprice": "",
# "mallName": "라임나무",
# "productId": "10710795782",
# "productType": "2",
# "brand": "",
# "maker": "",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "DIY 명화그리기 풍수 해바라기 유화 <b>그림</b> 그리기 집순이 취미",
# "link": "https://search.shopping.naver.com/gate.nhn?id=82565022977",
# "image": "https://shopping-phinf.pstatic.net/main_8256502/82565022977.1.jpg",
# "lprice": "10800",
# "hprice": "",
# "mallName": "미가유통센터",
# "productId": "82565022977",
# "productType": "2",
# "brand": "",
# "maker": "",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "돈들어오는<b>그림</b> 황금 돈나무 인테리어 대형 거실액자 <b>그림</b>액자 집들이선물",
# "link": "https://search.shopping.naver.com/gate.nhn?id=82494339702",
# "image": "https://shopping-phinf.pstatic.net/main_8249433/82494339702.jpg",
# "lprice": "45000",
# "hprice": "",
# "mallName": "지앤씨 프레임",
# "productId": "82494339702",
# "productType": "2",
# "brand": "",
# "maker": "",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "발레로즈 거실<b>그림</b> 인테리어 유화색칠하기 캔버스 포스터 백드롭페인팅 아트 액자 개업 집들이 선물",
# "link": "https://search.shopping.naver.com/gate.nhn?id=82990871846",
# "image": "https://shopping-phinf.pstatic.net/main_8299087/82990871846.jpg",
# "lprice": "23000",
# "hprice": "",
# "mallName": "리츠센",
# "productId": "82990871846",
# "productType": "2",
# "brand": "리츠센",
# "maker": "",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "리빙듀오 DIY 명화그리기 해바라기 유화그리기세트 2+1 꽃 <b>그림</b> 캔버스 페인팅 색칠하기",
# "link": "https://search.shopping.naver.com/gate.nhn?id=29639922326",
# "image": "https://shopping-phinf.pstatic.net/main_2963992/29639922326.20211111233607.jpg",
# "lprice": "2930",
# "hprice": "",
# "mallName": "네이버",
# "productId": "29639922326",
# "productType": "1",
# "brand": "리빙듀오",
# "maker": "리빙듀오",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "DIY 명화그리기 <b>그림</b> 고흐 모네 해바라기 꽃 풍수 유화그리기 세트 액자 색칠하기",
# "link": "https://search.shopping.naver.com/gate.nhn?id=82514882389",
# "image": "https://shopping-phinf.pstatic.net/main_8251488/82514882389.17.jpg",
# "lprice": "18900",
# "hprice": "",
# "mallName": "윹토끼의 잡화점",
# "productId": "82514882389",
# "productType": "2",
# "brand": "",
# "maker": "",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "유화 해바라기 <b>그림</b> 화가가 직접 그린 수작업 작품 5개",
# "link": "https://search.shopping.naver.com/gate.nhn?id=27443974862",
# "image": "https://shopping-phinf.pstatic.net/main_2744397/27443974862.20210727150851.jpg",
# "lprice": "120000",
# "hprice": "",
# "mallName": "네이버",
# "productId": "27443974862",
# "productType": "1",
# "brand": "",
# "maker": "",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "DIY 명화 그리기 <b>그림</b> 유화그리기 세트 해바라기 보태니컬 풍경 꽃 동물 모던 액자캔버스",
# "link": "https://search.shopping.naver.com/gate.nhn?id=82587661761",
# "image": "https://shopping-phinf.pstatic.net/main_8258766/82587661761.14.jpg",
# "lprice": "11900",
# "hprice": "",
# "mallName": "포토벨로 잡화점",
# "productId": "82587661761",
# "productType": "2",
# "brand": "",
# "maker": "",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "유화색칠하기 DIY 명화그리기 해바라기 유화그리기세트 집순이취미 3 1",
# "link": "https://search.shopping.naver.com/gate.nhn?id=27398127821",
# "image": "https://shopping-phinf.pstatic.net/main_2739812/27398127821.20210602043404.jpg",
# "lprice": "5310",
# "hprice": "",
# "mallName": "네이버",
# "productId": "27398127821",
# "productType": "1",
# "brand": "",
# "maker": "",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "돈들어오는<b>그림</b> 황금돈나무 인테리어 <b>그림</b>액자 집들이 개업선물 두꺼비집가리개",
# "link": "https://search.shopping.naver.com/gate.nhn?id=82530095738",
# "image": "https://shopping-phinf.pstatic.net/main_8253009/82530095738.jpg",
# "lprice": "51000",
# "hprice": "",
# "mallName": "씽크어스 프레임",
# "productId": "82530095738",
# "productType": "2",
# "brand": "",
# "maker": "씽크어스",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "에덴미술 스마일 <b>그림</b> 액자 행운을 부르는 해피 거실 현관 인테리어 28종 집들이 선물",
# "link": "https://search.shopping.naver.com/gate.nhn?id=28577506775",
# "image": "https://shopping-phinf.pstatic.net/main_2857750/28577506775.20210825205046.jpg",
# "lprice": "12900",
# "hprice": "",
# "mallName": "네이버",
# "productId": "28577506775",
# "productType": "1",
# "brand": "에덴미술",
# "maker": "",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "퀄리티보장 장기보관 가능 패브릭트리 포스터 크리스마스트리 전구 코로나 데이트",
# "link": "https://search.shopping.naver.com/gate.nhn?id=81453859298",
# "image": "https://shopping-phinf.pstatic.net/main_8145385/81453859298.3.jpg",
# "lprice": "13900",
# "hprice": "",
# "mallName": "당신의공간",
# "productId": "81453859298",
# "productType": "2",
# "brand": "",
# "maker": "",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "인테리어 명화 액자 10종 대형 와이드 거실 <b>그림</b> 고흐 모네 클림트 풍경 추상화",
# "link": "https://search.shopping.naver.com/gate.nhn?id=27603159548",
# "image": "https://shopping-phinf.pstatic.net/main_2760315/27603159548.20210616233530.jpg",
# "lprice": "62500",
# "hprice": "",
# "mallName": "네이버",
# "productId": "27603159548",
# "productType": "1",
# "brand": "",
# "maker": "",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "패브릭 포스터 인테리어 바다 <b>그림</b> 해바라기 액자 캔버스 풍경 크리스마스 두꺼비집 가리개",
# "link": "https://search.shopping.naver.com/gate.nhn?id=13480844791",
# "image": "https://shopping-phinf.pstatic.net/main_1348084/13480844791.3.jpg",
# "lprice": "10690",
# "hprice": "",
# "mallName": "판다스틱",
# "productId": "13480844791",
# "productType": "2",
# "brand": "판다스틱",
# "maker": "판다스틱",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "텐바이텐 그레고리 추상화 거실액자 대형<b>그림</b>",
# "link": "https://search.shopping.naver.com/gate.nhn?id=23681789031",
# "image": "https://shopping-phinf.pstatic.net/main_2368178/23681789031.20200804172553.jpg",
# "lprice": "50000",
# "hprice": "",
# "mallName": "네이버",
# "productId": "23681789031",
# "productType": "1",
# "brand": "텐바이텐",
# "maker": "제이지클리",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "나의 유럽 모먼트 풍경 사진 인테리어 액자 포스터 100종",
# "link": "https://search.shopping.naver.com/gate.nhn?id=82915004877",
# "image": "https://shopping-phinf.pstatic.net/main_8291500/82915004877.jpg",
# "lprice": "2900",
# "hprice": "",
# "mallName": "멜팅스튜디오",
# "productId": "82915004877",
# "productType": "2",
# "brand": "멜팅스튜디오",
# "maker": "멜팅스튜디오",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "돈을 부르는 해바라기 액자 유화<b>그림</b> 거실액자",
# "link": "https://search.shopping.naver.com/gate.nhn?id=28620396614",
# "image": "https://shopping-phinf.pstatic.net/main_2862039/28620396614.20210828233557.jpg",
# "lprice": "35000",
# "hprice": "",
# "mallName": "네이버",
# "productId": "28620396614",
# "productType": "1",
# "brand": "",
# "maker": "",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "DIY 유화색칠하기 아크릴 캔버스페인팅 <b>그림</b> 명화 그리기 쉬운 세트 피포페인팅 아님",
# "link": "https://search.shopping.naver.com/gate.nhn?id=82828044184",
# "image": "https://shopping-phinf.pstatic.net/main_8282804/82828044184.3.jpg",
# "lprice": "15000",
# "hprice": "",
# "mallName": "최화룸",
# "productId": "82828044184",
# "productType": "2",
# "brand": "",
# "maker": "",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# }
# ]
# }
