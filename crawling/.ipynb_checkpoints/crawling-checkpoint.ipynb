# %%
import requests
import urllib
import json
import time

# %%
start_time = time.time()

query = "그림 인테리어 캔버스 아트" #검색을 원하는 문자열
display = "100" #기본10 최대1000
start = "1" #최소1 최대1000
sort = "sim" #정렬 옵션 : sim(유사도), date(날짜순), asc(가격오름차순), dsc(가격내림차순)

query = urllib.parse.quote(query)

url = "https://openapi.naver.com/v1/search/shop?query=" + query + "&display=" + display+ "&start=" + start + "&sort=" + sort 

client_id = "ns_lsVeiLXPoagHNyqXD"
client_secret = "tKVxt4TFYp"

request = urllib.request.Request(url)
request.add_header('X-Naver-Client-Id', client_id)
request.add_header('X-Naver-Client-Secret', client_secret)

response = urllib.request.urlopen(request)
results = response.read().decode('utf-8')
print(results)
results_json = json.loads(results)

print(f"Query Time : {time.time()-start_time}")
# Out:
# {
# "lastBuildDate": "Sat, 11 Dec 2021 19:29:00 +0900",
# "total": 595596,
# "start": 1,
# "display": 100,
# "items": [
# {
# "title": "패브릭 포스터 <b>인테리어</b> 바다 <b>그림</b> 해바라기 액자 <b>캔버스</b> 풍경 크리스마스 두꺼비집 가리개",
# "link": "https://search.shopping.naver.com/gate.nhn?id=13480844791",
# "image": "https://shopping-phinf.pstatic.net/main_1348084/13480844791.3.jpg",
# "lprice": "10690",
# "hprice": "",
# "mallName": "판다스틱",
# "productId": "13480844791",
# "productType": "2",
# "brand": "판다스틱",
# "maker": "판다스틱",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "<b>인테리어</b> 액자 <b>캔버스</b> 카페 식물 해바라기 꽃 <b>그림</b> 패브릭 포스터 거실 개업 신혼집 집들이 선물",
# "link": "https://search.shopping.naver.com/gate.nhn?id=11455628156",
# "image": "https://shopping-phinf.pstatic.net/main_1145562/11455628156.4.jpg",
# "lprice": "3900",
# "hprice": "",
# "mallName": "프레임아트",
# "productId": "11455628156",
# "productType": "2",
# "brand": "프레임아트",
# "maker": "프레임아트",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "사진인화 대형 <b>그림</b> <b>캔버스 아트</b> 프린트 사진인화 원목액자 A4 A3 A2 A1 A0",
# "link": "https://search.shopping.naver.com/gate.nhn?id=81839628388",
# "image": "https://shopping-phinf.pstatic.net/main_8183962/81839628388.39.jpg",
# "lprice": "2000",
# "hprice": "",
# "mallName": "파인아트 라이프 사진인화",
# "productId": "81839628388",
# "productType": "2",
# "brand": "",
# "maker": "",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "<b>캔버스</b>액자 주문제작 대형 <b>캔버스</b> 인쇄 출력 사진 인화",
# "link": "https://search.shopping.naver.com/gate.nhn?id=13452357786",
# "image": "https://shopping-phinf.pstatic.net/main_1345235/13452357786.jpg",
# "lprice": "8400",
# "hprice": "",
# "mallName": "유홍아트",
# "productId": "13452357786",
# "productType": "2",
# "brand": "유홍아트",
# "maker": "",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "카페 감성 <b>인테리어</b> 액자 <b>캔버스</b> 식물 해바라기 바다 꽃 <b>그림</b> 패브릭 포스터 거실 개업 신혼집 집들이 선물",
# "link": "https://search.shopping.naver.com/gate.nhn?id=82040528357",
# "image": "https://shopping-phinf.pstatic.net/main_8204052/82040528357.jpg",
# "lprice": "3900",
# "hprice": "",
# "mallName": "프레임아트",
# "productId": "82040528357",
# "productType": "2",
# "brand": "프레임아트",
# "maker": "프레임아트",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "앙리 마티스 <b>인테리어</b> <b>그림</b> 액자 <b>캔버스</b> 포스터 드로잉",
# "link": "https://search.shopping.naver.com/gate.nhn?id=12303500025",
# "image": "https://shopping-phinf.pstatic.net/main_1230350/12303500025.7.jpg",
# "lprice": "5000",
# "hprice": "",
# "mallName": "봄날프로젝트",
# "productId": "12303500025",
# "productType": "2",
# "brand": "봄날프로젝트",
# "maker": "봄날프로젝트",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "명화 빈티지 <b>인테리어</b> <b>그림</b> 액자 <b>캔버스</b> 포스터 모네 앙리마티스 고흐 클림트",
# "link": "https://search.shopping.naver.com/gate.nhn?id=82810659021",
# "image": "https://shopping-phinf.pstatic.net/main_8281065/82810659021.7.jpg",
# "lprice": "5000",
# "hprice": "",
# "mallName": "봄날프로젝트",
# "productId": "82810659021",
# "productType": "2",
# "brand": "봄날프로젝트",
# "maker": "봄날프로젝트",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "팝<b>아트</b> 초상화 커플 기념일 <b>캔버스</b> 액자 캐리커쳐 결혼 집들이 사진 인화 선물 <b>그림</b> 제작",
# "link": "https://search.shopping.naver.com/gate.nhn?id=11906545120",
# "image": "https://shopping-phinf.pstatic.net/main_1190654/11906545120.2.jpg",
# "lprice": "29000",
# "hprice": "",
# "mallName": "루비아트",
# "productId": "11906545120",
# "productType": "2",
# "brand": "",
# "maker": "",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "<b>인테리어</b> <b>그림</b> 액자 <b>캔버스</b> 포스터",
# "link": "https://search.shopping.naver.com/gate.nhn?id=10129639201",
# "image": "https://shopping-phinf.pstatic.net/main_1012963/10129639201.15.jpg",
# "lprice": "5000",
# "hprice": "",
# "mallName": "봄날프로젝트",
# "productId": "10129639201",
# "productType": "2",
# "brand": "봄날프로젝트",
# "maker": "봄날프로젝트",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "사과<b>그림</b> 31종 풍수 <b>인테리어 캔버스</b> 액자 주방 거실",
# "link": "https://search.shopping.naver.com/gate.nhn?id=80807836810",
# "image": "https://shopping-phinf.pstatic.net/main_8080783/80807836810.3.jpg",
# "lprice": "14500",
# "hprice": "",
# "mallName": "아란아트",
# "productId": "80807836810",
# "productType": "2",
# "brand": "아란아트",
# "maker": "아란아트",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "대형 바다 패브릭 포스터 <b>인테리어 캔버스</b> 액자 풍경 사진 윤슬 파도 천 물 <b>그림</b> 수영장",
# "link": "https://search.shopping.naver.com/gate.nhn?id=83139257813",
# "image": "https://shopping-phinf.pstatic.net/main_8313925/83139257813.1.jpg",
# "lprice": "10690",
# "hprice": "",
# "mallName": "판다스틱",
# "productId": "83139257813",
# "productType": "2",
# "brand": "판다스틱",
# "maker": "판다스틱",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "위<b>아트</b> 프리미엄 <b>캔버스</b> 명화 <b>인테리어</b><b>그림</b> 시리즈 액자세트 18종",
# "link": "https://search.shopping.naver.com/gate.nhn?id=82497599776",
# "image": "https://shopping-phinf.pstatic.net/main_8249759/82497599776.3.jpg",
# "lprice": "78000",
# "hprice": "",
# "mallName": "위아트",
# "productId": "82497599776",
# "productType": "2",
# "brand": "위아트",
# "maker": "",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "아이방 우리집꾸미기 동물<b>그림</b> 팝<b>아트</b> 대형 <b>캔버스</b>액자",
# "link": "https://search.shopping.naver.com/gate.nhn?id=81769921786",
# "image": "https://shopping-phinf.pstatic.net/main_8176992/81769921786.jpg",
# "lprice": "19900",
# "hprice": "",
# "mallName": "아트앤아트",
# "productId": "81769921786",
# "productType": "2",
# "brand": "",
# "maker": "",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "앙리마티스 명화 <b>그림 인테리어</b> 액자 <b>캔버스</b> 카페 패브릭 포스터",
# "link": "https://search.shopping.naver.com/gate.nhn?id=81407031328",
# "image": "https://shopping-phinf.pstatic.net/main_8140703/81407031328.1.jpg",
# "lprice": "4900",
# "hprice": "",
# "mallName": "프레임아트",
# "productId": "81407031328",
# "productType": "2",
# "brand": "프레임아트",
# "maker": "프레임아트",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "에덴미술 두요 김민정 작가 유화 <b>그림</b> <b>아트</b> 프린팅 거실 <b>캔버스</b> 액자 사랑아",
# "link": "https://search.shopping.naver.com/gate.nhn?id=18470640915",
# "image": "https://shopping-phinf.pstatic.net/main_1847064/18470640915.20190402170046.jpg",
# "lprice": "38900",
# "hprice": "",
# "mallName": "네이버",
# "productId": "18470640915",
# "productType": "1",
# "brand": "에덴미술",
# "maker": "",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "해바라기 <b>그림</b> 액자 <b>캔버스</b> 포스터",
# "link": "https://search.shopping.naver.com/gate.nhn?id=81288698815",
# "image": "https://shopping-phinf.pstatic.net/main_8128869/81288698815.3.jpg",
# "lprice": "5000",
# "hprice": "",
# "mallName": "봄날프로젝트",
# "productId": "81288698815",
# "productType": "2",
# "brand": "봄날프로젝트",
# "maker": "봄날프로젝트",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "[당일발송]돈들어오는 해바라기 <b>그림</b> 액자 45종 거실 풍수 <b>인테리어 캔버스</b> 소품 개업 선물",
# "link": "https://search.shopping.naver.com/gate.nhn?id=83114730397",
# "image": "https://shopping-phinf.pstatic.net/main_8311473/83114730397.3.jpg",
# "lprice": "10900",
# "hprice": "",
# "mallName": "인메이블",
# "productId": "83114730397",
# "productType": "2",
# "brand": "인메이블",
# "maker": "",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "diy명화그리기 피포페인팅 유화 <b>그림</b> 색칠하기 유화 <b>캔버스</b> 해바라기 고흐 그리기세트",
# "link": "https://search.shopping.naver.com/gate.nhn?id=82452479669",
# "image": "https://shopping-phinf.pstatic.net/main_8245247/82452479669.7.jpg",
# "lprice": "11900",
# "hprice": "",
# "mallName": "소소오늘",
# "productId": "82452479669",
# "productType": "2",
# "brand": "아트조이",
# "maker": "",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "빈센트반고흐 <b>캔버스</b> 액자 대형 명화 <b>그림</b> 반 고흐 별이빛나는밤 해바라기 아몬드나무 카페테라스",
# "link": "https://search.shopping.naver.com/gate.nhn?id=81524189693",
# "image": "https://shopping-phinf.pstatic.net/main_8152418/81524189693.5.jpg",
# "lprice": "7900",
# "hprice": "",
# "mallName": "프레임아트",
# "productId": "81524189693",
# "productType": "2",
# "brand": "프레임아트",
# "maker": "프레임아트",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "학교납품업체 diy 명화그리기 특<b>그림</b> 유화그리기 세트 액자 해바라기 보태니컬 풍경 꽃 동물 모던 <b>캔버스</b>페인팅 취미 피포 앙리마티스 고흐 <b>그림</b> <b>아트</b> <b>인테리어</b> 미술 정물 풍경 장식",
# "link": "https://search.shopping.naver.com/gate.nhn?id=10276930174",
# "image": "https://shopping-phinf.pstatic.net/main_1027693/10276930174.15.jpg",
# "lprice": "4300",
# "hprice": "",
# "mallName": "아트픽스",
# "productId": "10276930174",
# "productType": "2",
# "brand": "아트픽스",
# "maker": "",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "돈 들어오는 사과 과일 <b>캔버스</b> <b>그림</b> 액자 3종 주방 거실 풍수 <b>인테리어</b> 사무실 개업 선물",
# "link": "https://search.shopping.naver.com/gate.nhn?id=83580088557",
# "image": "https://shopping-phinf.pstatic.net/main_8358008/83580088557.jpg",
# "lprice": "13700",
# "hprice": "",
# "mallName": "지누스코",
# "productId": "83580088557",
# "productType": "2",
# "brand": "",
# "maker": "",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "클로드모네 <b>인테리어</b> 액자 거실 대형 <b>캔버스</b> 명화 <b>그림</b> 모네 양산을든여인 수련 베테유 해바라기",
# "link": "https://search.shopping.naver.com/gate.nhn?id=82004589184",
# "image": "https://shopping-phinf.pstatic.net/main_8200458/82004589184.2.jpg",
# "lprice": "7900",
# "hprice": "",
# "mallName": "프레임아트",
# "productId": "82004589184",
# "productType": "2",
# "brand": "프레임아트",
# "maker": "프레임아트",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "북유럽 코끼리 <b>그림</b> 액자 대형 <b>캔버스</b> <b>그림</b> 거실 현관 돈들어오는 벽걸이 <b>그림</b>",
# "link": "https://search.shopping.naver.com/gate.nhn?id=82811361896",
# "image": "https://shopping-phinf.pstatic.net/main_8281136/82811361896.jpg",
# "lprice": "58000",
# "hprice": "",
# "mallName": "앤디하우스",
# "productId": "82811361896",
# "productType": "2",
# "brand": "",
# "maker": "",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "돈들어오는 해바라기 액자 <b>캔버스</b> <b>그림</b> 풍수 대형 와이드 거실 현관 개업 오픈 집들이 선물",
# "link": "https://search.shopping.naver.com/gate.nhn?id=82012488051",
# "image": "https://shopping-phinf.pstatic.net/main_8201248/82012488051.jpg",
# "lprice": "59800",
# "hprice": "",
# "mallName": "프레임아트",
# "productId": "82012488051",
# "productType": "2",
# "brand": "프레임아트",
# "maker": "프레임아트",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "돈 들어오는 사과 과일 <b>캔버스</b> <b>그림</b> 액자 3종 주방 거실 풍수 <b>인테리어</b> 사무실 개업 선물",
# "link": "https://search.shopping.naver.com/gate.nhn?id=83580067730",
# "image": "https://shopping-phinf.pstatic.net/main_8358006/83580067730.jpg",
# "lprice": "13800",
# "hprice": "",
# "mallName": "다정웰빙몰",
# "productId": "83580067730",
# "productType": "2",
# "brand": "",
# "maker": "",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "사진인화 A1 A2 A3 A4 핸드폰사진 <b>그림</b> 포스터 <b>캔버스 아트</b>프린트 인쇄 출력",
# "link": "https://search.shopping.naver.com/gate.nhn?id=82938764501",
# "image": "https://shopping-phinf.pstatic.net/main_8293876/82938764501.1.jpg",
# "lprice": "1500",
# "hprice": "",
# "mallName": "솔빈이네액자가게",
# "productId": "82938764501",
# "productType": "2",
# "brand": "",
# "maker": "",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "블루 파스텔 추상화 북유럽 <b>캔버스</b>액자 <b>인테리어</b> 액자 거실 <b>그림</b>액자",
# "link": "https://search.shopping.naver.com/gate.nhn?id=82909436271",
# "image": "https://shopping-phinf.pstatic.net/main_8290943/82909436271.jpg",
# "lprice": "32000",
# "hprice": "",
# "mallName": "르비안느 아트",
# "productId": "82909436271",
# "productType": "2",
# "brand": "",
# "maker": "",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "아란<b>아트</b> <b>캔버스</b>액자 맞춤액자 웨딩 가족사진",
# "link": "https://search.shopping.naver.com/gate.nhn?id=23565855288",
# "image": "https://shopping-phinf.pstatic.net/main_2356585/23565855288.20200724174259.jpg",
# "lprice": "14400",
# "hprice": "",
# "mallName": "네이버",
# "productId": "23565855288",
# "productType": "1",
# "brand": "",
# "maker": "",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "DIY 명화그리기 해바라기 <b>그림</b> 유화 액자 집순이취미 세트 <b>캔버스</b> 풍경 피포페인팅",
# "link": "https://search.shopping.naver.com/gate.nhn?id=82498277283",
# "image": "https://shopping-phinf.pstatic.net/main_8249827/82498277283.3.jpg",
# "lprice": "16400",
# "hprice": "",
# "mallName": "복복샵",
# "productId": "82498277283",
# "productType": "2",
# "brand": "",
# "maker": "피포페인팅",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "유홍<b>아트</b> 북유럽 집들이 두꺼비집 가리개 배전함 가리개 차단기 커버 <b>캔버스</b>액자 두께 99종",
# "link": "https://search.shopping.naver.com/gate.nhn?id=29657674503",
# "image": "https://shopping-phinf.pstatic.net/main_2965767/29657674503.20211112234622.jpg",
# "lprice": "28000",
# "hprice": "",
# "mallName": "네이버",
# "productId": "29657674503",
# "productType": "1",
# "brand": "유홍아트",
# "maker": "",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "두꺼비집 가리개, <b>인테리어</b> 액자 배전함 커버 현관 거실 명화 <b>캔버스</b> 일러스트 <b>그림</b> 6종",
# "link": "https://search.shopping.naver.com/gate.nhn?id=82566196235",
# "image": "https://shopping-phinf.pstatic.net/main_8256619/82566196235.jpg",
# "lprice": "25900",
# "hprice": "",
# "mallName": "SINGLERIDER",
# "productId": "82566196235",
# "productType": "2",
# "brand": "싱글라이더",
# "maker": "",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "[당일출발] 돈들어오는 푸른 사과 <b>그림</b> 액자 22종 대형 <b>캔버스</b> 생기 과일 주방 거실 풍수 <b>인테리어</b> 선물",
# "link": "https://search.shopping.naver.com/gate.nhn?id=83131794081",
# "image": "https://shopping-phinf.pstatic.net/main_8313179/83131794081.7.jpg",
# "lprice": "4600",
# "hprice": "",
# "mallName": "인메이블",
# "productId": "83131794081",
# "productType": "2",
# "brand": "인메이블",
# "maker": "",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "위<b>아트</b> 모지스 봄 <b>캔버스아트</b> <b>그림</b> 거실 <b>인테리어</b>",
# "link": "https://search.shopping.naver.com/gate.nhn?id=24102149207",
# "image": "https://shopping-phinf.pstatic.net/main_2410214/24102149207.20200909213603.jpg",
# "lprice": "6900",
# "hprice": "",
# "mallName": "네이버",
# "productId": "24102149207",
# "productType": "1",
# "brand": "",
# "maker": "",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "돈들어오는 모란 목단 꽃 풍수지리 <b>인테리어</b> 액자 <b>캔버스</b> <b>그림</b> 패브릭 포스터 집들이 개업 선물",
# "link": "https://search.shopping.naver.com/gate.nhn?id=81672855791",
# "image": "https://shopping-phinf.pstatic.net/main_8167285/81672855791.jpg",
# "lprice": "4900",
# "hprice": "",
# "mallName": "프레임아트",
# "productId": "81672855791",
# "productType": "2",
# "brand": "프레임아트",
# "maker": "프레임아트",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "작가<b>그림</b> <b>캔버스</b>액자 추상화 황금 노란 아이방포스터 연회",
# "link": "https://search.shopping.naver.com/gate.nhn?id=82353866715",
# "image": "https://shopping-phinf.pstatic.net/main_8235386/82353866715.2.jpg",
# "lprice": "56000",
# "hprice": "",
# "mallName": "OWN아트포스터",
# "productId": "82353866715",
# "productType": "2",
# "brand": "",
# "maker": "",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "돈들어오는 해바라기 <b>그림 인테리어</b> 액자 <b>캔버스</b> 패브릭 포스터 집들이 개업 선물",
# "link": "https://search.shopping.naver.com/gate.nhn?id=81436192871",
# "image": "https://shopping-phinf.pstatic.net/main_8143619/81436192871.2.jpg",
# "lprice": "4900",
# "hprice": "",
# "mallName": "프레임아트",
# "productId": "81436192871",
# "productType": "2",
# "brand": "프레임아트",
# "maker": "프레임아트",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "청량한 푸른 사과 <b>캔버스</b> 액자 재물운 금전운 거실 사무실 <b>인테리어</b>",
# "link": "https://search.shopping.naver.com/gate.nhn?id=82349676851",
# "image": "https://shopping-phinf.pstatic.net/main_8234967/82349676851.jpg",
# "lprice": "14500",
# "hprice": "",
# "mallName": "아란아트",
# "productId": "82349676851",
# "productType": "2",
# "brand": "아란아트",
# "maker": "아란아트",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "창문 <b>그림</b> 액자 26종 감성 <b>인테리어</b> 원룸 꾸미기 자연 사진 <b>캔버스</b> 패브릭 포스터",
# "link": "https://search.shopping.naver.com/gate.nhn?id=82054439838",
# "image": "https://shopping-phinf.pstatic.net/main_8205443/82054439838.5.jpg",
# "lprice": "3900",
# "hprice": "",
# "mallName": "에덴미술",
# "productId": "82054439838",
# "productType": "2",
# "brand": "인메이블",
# "maker": "",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "아란<b>아트</b> <b>인테리어</b> 모란꽃<b>그림</b> <b>캔버스</b>액자",
# "link": "https://search.shopping.naver.com/gate.nhn?id=14146772004",
# "image": "https://shopping-phinf.pstatic.net/main_1414677/14146772004.20200220042358.jpg",
# "lprice": "14900",
# "hprice": "",
# "mallName": "네이버",
# "productId": "14146772004",
# "productType": "1",
# "brand": "아란아트",
# "maker": "",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "에드워드호퍼 바다가 보이는 방 멋진거실<b>그림</b> <b>캔버스</b>액자",
# "link": "https://search.shopping.naver.com/gate.nhn?id=80912623370",
# "image": "https://shopping-phinf.pstatic.net/main_8091262/80912623370.jpg",
# "lprice": "14500",
# "hprice": "",
# "mallName": "아란아트",
# "productId": "80912623370",
# "productType": "2",
# "brand": "아란아트",
# "maker": "아란아트",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "힘찬 기운 호랑이 <b>그림</b> 액자 백호 풍수 <b>인테리어 캔버스</b> <b>그림</b>",
# "link": "https://search.shopping.naver.com/gate.nhn?id=83201207470",
# "image": "https://shopping-phinf.pstatic.net/main_8320120/83201207470.1.jpg",
# "lprice": "68000",
# "hprice": "",
# "mallName": "앤디하우스",
# "productId": "83201207470",
# "productType": "2",
# "brand": "",
# "maker": "",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "위모던 돈들어오는 풍수 <b>인테리어</b> 사과 고흐 해바라기 <b>그림</b> 포스터 사진 액자 <b>캔버스</b> 29종",
# "link": "https://search.shopping.naver.com/gate.nhn?id=82497825290",
# "image": "https://shopping-phinf.pstatic.net/main_8249782/82497825290.5.jpg",
# "lprice": "11900",
# "hprice": "",
# "mallName": "위모던",
# "productId": "82497825290",
# "productType": "2",
# "brand": "위모던",
# "maker": "",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "사진 카페 <b>인테리어캔버스 아트</b>빈 커피숍액자 CAFE H 25 A2사이즈",
# "link": "https://search.shopping.naver.com/gate.nhn?id=28533824174",
# "image": "https://shopping-phinf.pstatic.net/main_2853382/28533824174.20210822232025.jpg",
# "lprice": "33000",
# "hprice": "",
# "mallName": "네이버",
# "productId": "28533824174",
# "productType": "1",
# "brand": "",
# "maker": "",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "<b>인테리어</b>액자 <b>캔버스</b><b>그림</b> <b>ART</b>3 감동갤러리 <b>아트</b><b>그림</b>액",
# "link": "https://search.shopping.naver.com/gate.nhn?id=21952805346",
# "image": "https://shopping-phinf.pstatic.net/main_2195280/21952805346.20200212161656.jpg",
# "lprice": "27960",
# "hprice": "",
# "mallName": "네이버",
# "productId": "21952805346",
# "productType": "1",
# "brand": "",
# "maker": "",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "<b>인테리어</b> <b>그림</b> 액자 <b>캔버스</b> 포스터 바우하우스 100주년",
# "link": "https://search.shopping.naver.com/gate.nhn?id=82394721052",
# "image": "https://shopping-phinf.pstatic.net/main_8239472/82394721052.jpg",
# "lprice": "5000",
# "hprice": "",
# "mallName": "봄날프로젝트",
# "productId": "82394721052",
# "productType": "2",
# "brand": "봄날프로젝트",
# "maker": "봄날프로젝트",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "<b>인테리어</b>액자 <b>캔버스</b><b>그림</b> <b>ART</b>2 감동갤러리",
# "link": "https://search.shopping.naver.com/gate.nhn?id=12381862887",
# "image": "https://shopping-phinf.pstatic.net/main_1238186/12381862887.20190118020502.jpg",
# "lprice": "27370",
# "hprice": "",
# "mallName": "네이버",
# "productId": "12381862887",
# "productType": "1",
# "brand": "",
# "maker": "",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "아란<b>아트</b> 모란꽃 목단꽃 돈들어오는 <b>그림</b> 한국화 <b>캔버스</b>액자 집들이선물",
# "link": "https://search.shopping.naver.com/gate.nhn?id=29161644985",
# "image": "https://shopping-phinf.pstatic.net/main_2916164/29161644985.20211009022622.jpg",
# "lprice": "14500",
# "hprice": "",
# "mallName": "네이버",
# "productId": "29161644985",
# "productType": "1",
# "brand": "아란아트",
# "maker": "",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "<b>인테리어</b>액자 <b>캔버스</b><b>그림</b> <b>ART</b>1 감동갤러리",
# "link": "https://search.shopping.naver.com/gate.nhn?id=21621671090",
# "image": "https://shopping-phinf.pstatic.net/main_2162167/21621671090.20191228181926.jpg",
# "lprice": "29070",
# "hprice": "",
# "mallName": "네이버",
# "productId": "21621671090",
# "productType": "1",
# "brand": "",
# "maker": "",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "감성 모던<b>아트</b> <b>인테리어</b><b>그림</b> <b>캔버스</b>액자 <b>그림</b>액자",
# "link": "https://search.shopping.naver.com/gate.nhn?id=29898831518",
# "image": "https://shopping-phinf.pstatic.net/main_2989883/29898831518.20211130212117.jpg",
# "lprice": "15900",
# "hprice": "",
# "mallName": "네이버",
# "productId": "29898831518",
# "productType": "1",
# "brand": "",
# "maker": "",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "아란<b>아트</b> 르네 마그리트 <b>캔버스</b><b>그림</b>액자 카페 거실<b>인테리어</b> 꾸미기",
# "link": "https://search.shopping.naver.com/gate.nhn?id=29625341795",
# "image": "https://shopping-phinf.pstatic.net/main_2962534/29625341795.20211110215453.jpg",
# "lprice": "2900",
# "hprice": "",
# "mallName": "네이버",
# "productId": "29625341795",
# "productType": "1",
# "brand": "아란아트",
# "maker": "",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "위<b>아트</b> 프리미엄 <b>캔버스</b> 명화 <b>인테리어</b><b>그림</b> 시리즈 액자세트 18종",
# "link": "https://search.shopping.naver.com/gate.nhn?id=82739488022",
# "image": "https://shopping-phinf.pstatic.net/main_8273948/82739488022.jpg",
# "lprice": "78000",
# "hprice": "",
# "mallName": "위아트",
# "productId": "82739488022",
# "productType": "2",
# "brand": "위아트",
# "maker": "",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "빈센트 반 고흐 명화<b>그림 인테리어 캔버스</b>액자 80종",
# "link": "https://search.shopping.naver.com/gate.nhn?id=82809960169",
# "image": "https://shopping-phinf.pstatic.net/main_8280996/82809960169.2.jpg",
# "lprice": "14400",
# "hprice": "",
# "mallName": "더 아트컴퍼니",
# "productId": "82809960169",
# "productType": "2",
# "brand": "",
# "maker": "",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "<b>아트</b>빈 해바라기 <b>그림 인테리어 캔버스</b>액자 size S 11",
# "link": "https://search.shopping.naver.com/gate.nhn?id=29538675174",
# "image": "https://shopping-phinf.pstatic.net/main_2953867/29538675174.20211104193521.jpg",
# "lprice": "32050",
# "hprice": "",
# "mallName": "네이버",
# "productId": "29538675174",
# "productType": "1",
# "brand": "",
# "maker": "",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "NB HB <b>인테리어 캔버스아트</b> 소품 꾸미기 819",
# "link": "https://search.shopping.naver.com/gate.nhn?id=29553298228",
# "image": "https://shopping-phinf.pstatic.net/main_2955329/29553298228.20211105222830.jpg",
# "lprice": "23360",
# "hprice": "",
# "mallName": "네이버",
# "productId": "29553298228",
# "productType": "1",
# "brand": "",
# "maker": "",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "<b>아트</b><b>캔버스</b> 모네 요트경주 대 <b>인테리어</b><b>그림</b>액자 100X50",
# "link": "https://search.shopping.naver.com/gate.nhn?id=28719324761",
# "image": "https://shopping-phinf.pstatic.net/main_2871932/28719324761.20210906015220.jpg",
# "lprice": "39000",
# "hprice": "",
# "mallName": "네이버",
# "productId": "28719324761",
# "productType": "1",
# "brand": "",
# "maker": "",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "콘야자 나뭇잎<b>그림</b> 보태니컬<b>아트</b> <b>캔버스</b>액자 식물액자",
# "link": "https://search.shopping.naver.com/gate.nhn?id=21436821661",
# "image": "https://shopping-phinf.pstatic.net/main_2143682/21436821661.20191203163406.jpg",
# "lprice": "3080",
# "hprice": "",
# "mallName": "네이버",
# "productId": "21436821661",
# "productType": "1",
# "brand": "",
# "maker": "",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "<b>인테리어</b> 소품 꾸미기 <b>캔버스아트</b> 11928 <b>인테리어</b> 소품",
# "link": "https://search.shopping.naver.com/gate.nhn?id=28631612255",
# "image": "https://shopping-phinf.pstatic.net/main_2863161/28631612255.20210830012317.jpg",
# "lprice": "14860",
# "hprice": "",
# "mallName": "네이버",
# "productId": "28631612255",
# "productType": "1",
# "brand": "",
# "maker": "",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "<b>인테리어</b> 소품 꾸미기 <b>캔버스아트</b> 11928",
# "link": "https://search.shopping.naver.com/gate.nhn?id=21237271239",
# "image": "https://shopping-phinf.pstatic.net/main_2123727/21237271239.20191105213132.jpg",
# "lprice": "14990",
# "hprice": "",
# "mallName": "네이버",
# "productId": "21237271239",
# "productType": "1",
# "brand": "",
# "maker": "",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "<b>인테리어</b> 소품 꾸미기 <b>캔버스아트</b> HB 51",
# "link": "https://search.shopping.naver.com/gate.nhn?id=27291657215",
# "image": "https://shopping-phinf.pstatic.net/main_2729165/27291657215.20210920014613.jpg",
# "lprice": "11190",
# "hprice": "",
# "mallName": "네이버",
# "productId": "27291657215",
# "productType": "1",
# "brand": "",
# "maker": "",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "<b>인테리어</b>액자 <b>캔버스</b><b>그림</b> <b>ART</b>1 감동갤러리 <b>아트</b><b>그림</b>액",
# "link": "https://search.shopping.naver.com/gate.nhn?id=28890100118",
# "image": "https://shopping-phinf.pstatic.net/main_2889010/28890100118.20210917194957.jpg",
# "lprice": "27370",
# "hprice": "",
# "mallName": "네이버",
# "productId": "28890100118",
# "productType": "1",
# "brand": "",
# "maker": "",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "워너비<b>아트</b> <b>캔버스</b>액자 유화<b>그림</b> 부귀의 해바라기<b>그림</b>액자 10호",
# "link": "https://search.shopping.naver.com/gate.nhn?id=26338936311",
# "image": "https://shopping-phinf.pstatic.net/main_2633893/26338936311.20210312201006.jpg",
# "lprice": "142700",
# "hprice": "",
# "mallName": "네이버",
# "productId": "26338936311",
# "productType": "1",
# "brand": "",
# "maker": "",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "구스타프클림트 <b>인테리어</b> 액자 <b>캔버스</b> 명화 <b>그림</b> 클림트 키스 아테제 뮤직 패브릭 포스터",
# "link": "https://search.shopping.naver.com/gate.nhn?id=81941678114",
# "image": "https://shopping-phinf.pstatic.net/main_8194167/81941678114.1.jpg",
# "lprice": "7900",
# "hprice": "",
# "mallName": "프레임아트",
# "productId": "81941678114",
# "productType": "2",
# "brand": "프레임아트",
# "maker": "프레임아트",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "스마일 <b>인테리어</b> <b>그림</b> 액자 <b>캔버스</b> 포스터 50x50cm 60x60cm",
# "link": "https://search.shopping.naver.com/gate.nhn?id=82927573959",
# "image": "https://shopping-phinf.pstatic.net/main_8292757/82927573959.jpg",
# "lprice": "14000",
# "hprice": "",
# "mallName": "봄날프로젝트",
# "productId": "82927573959",
# "productType": "2",
# "brand": "봄날프로젝트",
# "maker": "봄날프로젝트",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "NEW 하비 직사각 액자 53 46 직9호 보급형<b>캔버스</b> 단체미술수업 미술재료 <b>캔버스아트</b>",
# "link": "https://search.shopping.naver.com/gate.nhn?id=22947563575",
# "image": "https://shopping-phinf.pstatic.net/main_2294756/22947563575.20200524143438.jpg",
# "lprice": "780",
# "hprice": "",
# "mallName": "네이버",
# "productId": "22947563575",
# "productType": "1",
# "brand": "",
# "maker": "",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "일본<b>그림</b> <b>캔버스아트</b> 도쿄 캣츠 퀼트 <b>그림</b> 거실 벽면 장식",
# "link": "https://search.shopping.naver.com/gate.nhn?id=28730701493",
# "image": "https://shopping-phinf.pstatic.net/main_2873070/28730701493.20210906211346.jpg",
# "lprice": "17450",
# "hprice": "",
# "mallName": "네이버",
# "productId": "28730701493",
# "productType": "1",
# "brand": "",
# "maker": "",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "<b>아트</b><b>캔버스</b>캘리액자-은혜",
# "link": "https://search.shopping.naver.com/gate.nhn?id=25888482230",
# "image": "https://shopping-phinf.pstatic.net/main_2588848/25888482230.20210205203410.jpg",
# "lprice": "46680",
# "hprice": "",
# "mallName": "네이버",
# "productId": "25888482230",
# "productType": "1",
# "brand": "",
# "maker": "",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "<b>캔버스아트</b> <b>art</b>-676",
# "link": "https://search.shopping.naver.com/gate.nhn?id=11194881076",
# "image": "https://shopping-phinf.pstatic.net/main_1119488/11194881076.20170915073458.jpg",
# "lprice": "154712",
# "hprice": "",
# "mallName": "네이버",
# "productId": "11194881076",
# "productType": "1",
# "brand": "",
# "maker": "",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "H <b>인테리어</b> 소품 꾸미기 <b>캔버스아트</b> 11928 16130EA",
# "link": "https://search.shopping.naver.com/gate.nhn?id=28533641909",
# "image": "https://shopping-phinf.pstatic.net/main_2853364/28533641909.20210822222343.jpg",
# "lprice": "14360",
# "hprice": "",
# "mallName": "네이버",
# "productId": "28533641909",
# "productType": "1",
# "brand": "",
# "maker": "",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "에덴미술 두요 김민정 작가 유화 <b>그림</b> <b>아트</b> 프린팅 거실 <b>캔버스</b> 액자",
# "link": "https://search.shopping.naver.com/gate.nhn?id=17005707998",
# "image": "https://shopping-phinf.pstatic.net/main_1700570/17005707998.20190112163721.jpg",
# "lprice": "98000",
# "hprice": "",
# "mallName": "네이버",
# "productId": "17005707998",
# "productType": "1",
# "brand": "에덴미술",
# "maker": "",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "<b>아트</b><b>캔버스</b> 모네 장미정원 대 <b>인테리어</b><b>그림</b>액자 100X50",
# "link": "https://search.shopping.naver.com/gate.nhn?id=28608794240",
# "image": "https://shopping-phinf.pstatic.net/main_2860879/28608794240.20210828044300.jpg",
# "lprice": "81860",
# "hprice": "",
# "mallName": "네이버",
# "productId": "28608794240",
# "productType": "1",
# "brand": "",
# "maker": "",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "<b>캔버스아트</b> <b>art</b> 182 기분좋은 상상에너지",
# "link": "https://search.shopping.naver.com/gate.nhn?id=26384372012",
# "image": "https://shopping-phinf.pstatic.net/main_2638437/26384372012.20210316210357.jpg",
# "lprice": "36485",
# "hprice": "",
# "mallName": "네이버",
# "productId": "26384372012",
# "productType": "1",
# "brand": "",
# "maker": "",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "홈데코 <b>캔버스아트</b> 11928",
# "link": "https://search.shopping.naver.com/gate.nhn?id=10558177023",
# "image": "https://shopping-phinf.pstatic.net/main_1055817/10558177023.20171103051446.jpg",
# "lprice": "12140",
# "hprice": "",
# "mallName": "네이버",
# "productId": "10558177023",
# "productType": "1",
# "brand": "",
# "maker": "",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "ENE <b>캔버스아트</b> 액자프레임 <b>캔버스</b>운동화 HB-51",
# "link": "https://search.shopping.naver.com/gate.nhn?id=22421659325",
# "image": "https://shopping-phinf.pstatic.net/main_2242165/22421659325.20200408150754.jpg",
# "lprice": "12900",
# "hprice": "",
# "mallName": "네이버",
# "productId": "22421659325",
# "productType": "1",
# "brand": "",
# "maker": "",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "몬스테라1 나뭇잎<b>그림</b> 보태니컬<b>아트</b> 식물 <b>캔버스</b>액자",
# "link": "https://search.shopping.naver.com/gate.nhn?id=21642182773",
# "image": "https://shopping-phinf.pstatic.net/main_2164218/21642182773.20200101185244.jpg",
# "lprice": "3080",
# "hprice": "",
# "mallName": "네이버",
# "productId": "21642182773",
# "productType": "1",
# "brand": "",
# "maker": "",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "명작화가 <b>아트</b><b>캔버스</b> - 사과나무 특대 GD1112414",
# "link": "https://search.shopping.naver.com/gate.nhn?id=29887566505",
# "image": "https://shopping-phinf.pstatic.net/main_2988756/29887566505.20211210020456.jpg",
# "lprice": "46960",
# "hprice": "",
# "mallName": "네이버",
# "productId": "29887566505",
# "productType": "1",
# "brand": "",
# "maker": "",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "홈데코 <b>캔버스아트</b> Y 14367",
# "link": "https://search.shopping.naver.com/gate.nhn?id=27109735347",
# "image": "https://shopping-phinf.pstatic.net/main_2710973/27109735347.20210511183051.jpg",
# "lprice": "12900",
# "hprice": "",
# "mallName": "네이버",
# "productId": "27109735347",
# "productType": "1",
# "brand": "",
# "maker": "",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "일본<b>그림</b> <b>캔버스아트</b> 도쿄 일식이 걸려 세상 풍경을 <b>그림</b>으로 배경 <b>아트</b> 패브릭",
# "link": "https://search.shopping.naver.com/gate.nhn?id=28648592851",
# "image": "https://shopping-phinf.pstatic.net/main_2864859/28648592851.20210831050446.jpg",
# "lprice": "81040",
# "hprice": "",
# "mallName": "네이버",
# "productId": "28648592851",
# "productType": "1",
# "brand": "",
# "maker": "",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "<b>캔버스아트</b> <b>art</b>-678",
# "link": "https://search.shopping.naver.com/gate.nhn?id=11188735067",
# "image": "https://shopping-phinf.pstatic.net/main_1118873/11188735067.20170915002127.jpg",
# "lprice": "154712",
# "hprice": "",
# "mallName": "네이버",
# "productId": "11188735067",
# "productType": "1",
# "brand": "",
# "maker": "",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "<b>캔버스아트</b> <b>art</b>-177",
# "link": "https://search.shopping.naver.com/gate.nhn?id=25808995451",
# "image": "https://shopping-phinf.pstatic.net/main_2580899/25808995451.20210131200444.jpg",
# "lprice": "36485",
# "hprice": "",
# "mallName": "네이버",
# "productId": "25808995451",
# "productType": "1",
# "brand": "",
# "maker": "",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "TJW 꾸미기 <b>인테리어</b> HB 소품 51 <b>캔버스아트</b> ar20",
# "link": "https://search.shopping.naver.com/gate.nhn?id=22581950185",
# "image": "https://shopping-phinf.pstatic.net/main_2258195/22581950185.20200422161118.jpg",
# "lprice": "14180",
# "hprice": "",
# "mallName": "네이버",
# "productId": "22581950185",
# "productType": "1",
# "brand": "",
# "maker": "",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "해바라기 모란 꽃 카페 정사각 <b>그림 인테리어 캔버스</b> 액자 주방 침실 현관 집들이 선물",
# "link": "https://search.shopping.naver.com/gate.nhn?id=82082195872",
# "image": "https://shopping-phinf.pstatic.net/main_8208219/82082195872.1.jpg",
# "lprice": "7900",
# "hprice": "",
# "mallName": "프레임아트",
# "productId": "82082195872",
# "productType": "2",
# "brand": "프레임아트",
# "maker": "프레임아트",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "HUGH 미니바바 <b>인테리어</b>액자 <b>캔버스아트</b> <b>인테리어캔버스</b> 팝<b>아트</b>액자 셀프<b>인테리어</b>",
# "link": "https://search.shopping.naver.com/gate.nhn?id=21237007974",
# "image": "https://shopping-phinf.pstatic.net/main_2123700/21237007974.20191105202550.jpg",
# "lprice": "12800",
# "hprice": "",
# "mallName": "네이버",
# "productId": "21237007974",
# "productType": "1",
# "brand": "",
# "maker": "",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "생기<b>그림</b> 사과 <b>캔버스</b>액자 복을부르는<b>그림</b>",
# "link": "https://search.shopping.naver.com/gate.nhn?id=82349708245",
# "image": "https://shopping-phinf.pstatic.net/main_8234970/82349708245.jpg",
# "lprice": "14500",
# "hprice": "",
# "mallName": "아란아트",
# "productId": "82349708245",
# "productType": "2",
# "brand": "아란아트",
# "maker": "아란아트",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "카페<b>인테리어 캔버스</b>액자 <b>아트</b> <b>그림</b> 소품 빈티지 패러디 심슨 v-2",
# "link": "https://search.shopping.naver.com/gate.nhn?id=21237162435",
# "image": "https://shopping-phinf.pstatic.net/main_2123716/21237162435.20191105205542.jpg",
# "lprice": "15340",
# "hprice": "",
# "mallName": "네이버",
# "productId": "21237162435",
# "productType": "1",
# "brand": "",
# "maker": "",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "KZM 홈데코 <b>캔버스아트</b> HB_819 N3T3H035",
# "link": "https://search.shopping.naver.com/gate.nhn?id=10549436896",
# "image": "https://shopping-phinf.pstatic.net/main_1054943/10549436896.20180918022603.jpg",
# "lprice": "11190",
# "hprice": "",
# "mallName": "네이버",
# "productId": "10549436896",
# "productType": "1",
# "brand": "",
# "maker": "",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "후추통 런던드라마 <b>아트</b> 빈티지<b>캔버스아트</b>액자 심슨 패러디 4호",
# "link": "https://search.shopping.naver.com/gate.nhn?id=28578279625",
# "image": "https://shopping-phinf.pstatic.net/main_2857827/28578279625.20210826003218.jpg",
# "lprice": "15340",
# "hprice": "",
# "mallName": "네이버",
# "productId": "28578279625",
# "productType": "1",
# "brand": "",
# "maker": "",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "북유럽 감성 <b>인테리어</b> 액자 <b>캔버스</b> 창문 바다 꽃 사진 <b>그림</b> 포스터 50종 집들이 선물",
# "link": "https://search.shopping.naver.com/gate.nhn?id=83606931778",
# "image": "https://shopping-phinf.pstatic.net/main_8360693/83606931778.jpg",
# "lprice": "3500",
# "hprice": "",
# "mallName": "지누아트",
# "productId": "83606931778",
# "productType": "2",
# "brand": "",
# "maker": "",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "유니<b>아트</b> <b>캔버스</b>천 액자 소 423EA",
# "link": "https://search.shopping.naver.com/gate.nhn?id=26942683522",
# "image": "https://shopping-phinf.pstatic.net/main_2694268/26942683522.20210427211018.jpg",
# "lprice": "1130",
# "hprice": "",
# "mallName": "네이버",
# "productId": "26942683522",
# "productType": "1",
# "brand": "",
# "maker": "",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "<b>아트</b><b>캔버스</b> 모네 장미정원 특대 <b>인테리어</b><b>그림</b>액자 120X60",
# "link": "https://search.shopping.naver.com/gate.nhn?id=28578309982",
# "image": "https://shopping-phinf.pstatic.net/main_2857830/28578309982.20210826004420.jpg",
# "lprice": "39000",
# "hprice": "",
# "mallName": "네이버",
# "productId": "28578309982",
# "productType": "1",
# "brand": "",
# "maker": "",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "휴<b>아트</b> <b>캔버스아트</b> <b>art</b>-154",
# "link": "https://search.shopping.naver.com/gate.nhn?id=25302454358",
# "image": "https://shopping-phinf.pstatic.net/main_2530245/25302454358.20201220184614.jpg",
# "lprice": "28835",
# "hprice": "",
# "mallName": "네이버",
# "productId": "25302454358",
# "productType": "1",
# "brand": "",
# "maker": "",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "크리스탈 핑크 데이지 꽃 <b>그림</b> <b>캔버스</b> 액자 <b>인테리어</b> 풍수 해바라기 특허디자인 미리<b>아트</b>",
# "link": "https://search.shopping.naver.com/gate.nhn?id=82777571483",
# "image": "https://shopping-phinf.pstatic.net/main_8277757/82777571483.4.jpg",
# "lprice": "170000",
# "hprice": "",
# "mallName": "미리아트",
# "productId": "82777571483",
# "productType": "2",
# "brand": "",
# "maker": "",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "모던 <b>아트</b><b>캔버스</b> 얼룩말 <b>그림 인테리어</b> 액자 A2사이즈",
# "link": "https://search.shopping.naver.com/gate.nhn?id=29036773108",
# "image": "https://shopping-phinf.pstatic.net/main_2903677/29036773108.20210930021922.jpg",
# "lprice": "25810",
# "hprice": "",
# "mallName": "네이버",
# "productId": "29036773108",
# "productType": "1",
# "brand": "",
# "maker": "",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "카페<b>인테리어 캔버스</b>액자 <b>아트</b> <b>켄버스</b><b>그림</b> 비틀즈패러디23",
# "link": "https://search.shopping.naver.com/gate.nhn?id=28863220916",
# "image": "https://shopping-phinf.pstatic.net/main_2886322/28863220916.20210916003025.jpg",
# "lprice": "16500",
# "hprice": "",
# "mallName": "네이버",
# "productId": "28863220916",
# "productType": "1",
# "brand": "",
# "maker": "",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "위<b>아트</b> 인기명화 <b>인테리어</b><b>그림</b> <b>캔버스</b>액자 48종",
# "link": "https://search.shopping.naver.com/gate.nhn?id=82497603245",
# "image": "https://shopping-phinf.pstatic.net/main_8249760/82497603245.4.jpg",
# "lprice": "38000",
# "hprice": "",
# "mallName": "위아트",
# "productId": "82497603245",
# "productType": "2",
# "brand": "위아트",
# "maker": "",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "<b>아트</b> DIY 유화그리기 액자 <b>그림</b> 세트 <b>캔버스</b>페인팅",
# "link": "https://search.shopping.naver.com/gate.nhn?id=22195302335",
# "image": "https://shopping-phinf.pstatic.net/main_2219530/22195302335.20200314142641.jpg",
# "lprice": "12830",
# "hprice": "",
# "mallName": "네이버",
# "productId": "22195302335",
# "productType": "1",
# "brand": "",
# "maker": "",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "카페<b>인테리어 캔버스</b>액자 <b>아트</b> <b>켄버스</b><b>그림</b> 비틀즈패러디9",
# "link": "https://search.shopping.naver.com/gate.nhn?id=30032766643",
# "image": "https://shopping-phinf.pstatic.net/main_3003276/30032766643.20211210221412.jpg",
# "lprice": "14250",
# "hprice": "",
# "mallName": "네이버",
# "productId": "30032766643",
# "productType": "1",
# "brand": "",
# "maker": "",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "일본<b>그림</b> <b>캔버스아트</b> 도쿄 세상 풍경을 <b>그림</b>으로 일식이 배경에 침실 거실 보자기",
# "link": "https://search.shopping.naver.com/gate.nhn?id=28751644504",
# "image": "https://shopping-phinf.pstatic.net/main_2875164/28751644504.20210908045313.jpg",
# "lprice": "34760",
# "hprice": "",
# "mallName": "네이버",
# "productId": "28751644504",
# "productType": "1",
# "brand": "",
# "maker": "",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "휴<b>아트</b> <b>캔버스아트</b> <b>art</b>-205",
# "link": "https://search.shopping.naver.com/gate.nhn?id=10549465216",
# "image": "https://shopping-phinf.pstatic.net/main_1054946/10549465216.20161028001726.jpg",
# "lprice": "39500",
# "hprice": "",
# "mallName": "네이버",
# "productId": "10549465216",
# "productType": "1",
# "brand": "",
# "maker": "",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "<b>캔버스아트</b> <b>art</b>-113",
# "link": "https://search.shopping.naver.com/gate.nhn?id=10557877872",
# "image": "https://shopping-phinf.pstatic.net/main_1055787/10557877872.20170916085832.jpg",
# "lprice": "84975",
# "hprice": "",
# "mallName": "네이버",
# "productId": "10557877872",
# "productType": "1",
# "brand": "",
# "maker": "",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# },
# {
# "title": "<b>인테리어</b> 소품 꾸미기 <b>캔버스아트</b> 11928 ShareBlue1 597458EA",
# "link": "https://search.shopping.naver.com/gate.nhn?id=27360798356",
# "image": "https://shopping-phinf.pstatic.net/main_2736079/27360798356.20210529210700.jpg",
# "lprice": "16490",
# "hprice": "",
# "mallName": "네이버",
# "productId": "27360798356",
# "productType": "1",
# "brand": "",
# "maker": "",
# "category1": "가구/인테리어",
# "category2": "인테리어소품",
# "category3": "액자",
# "category4": "퍼즐/그림/사진액자"
#
# }
# ]
# }
#
# Query Time : 0.36513566970825195

# %%
url = results_json['items'][0]['image']
url
# Out:
# 'https://shopping-phinf.pstatic.net/main_2944843/29448439618.jpg'

# %%
results_json['items']
# Out:
# [{'title': '<b>그림</b>걸이 고하중(세트) 1WAY CH86018',
#   'link': 'https://search.shopping.naver.com/gate.nhn?id=83574748213',
#   'image': 'https://shopping-phinf.pstatic.net/main_8357474/83574748213.jpg',
#   'lprice': '5270',
#   'hprice': '',
#   'mallName': 'jungemall',
#   'productId': '83574748213',
#   'productType': '2',
#   'brand': '',
#   'maker': '',
#   'category1': '생활/건강',
#   'category2': '생활용품',
#   'category3': '생활잡화',
#   'category4': '신발관리도구'},
#  {'title': '<b>그림</b>걸이 고하중 각도조절부속 CH86119',
#   'link': 'https://search.shopping.naver.com/gate.nhn?id=83574747211',
#   'image': 'https://shopping-phinf.pstatic.net/main_8357474/83574747211.jpg',
#   'lprice': '6070',
#   'hprice': '',
#   'mallName': 'jungemall',
#   'productId': '83574747211',
#   'productType': '2',
#   'brand': '',
#   'maker': '',
#   'category1': '생활/건강',
#   'category2': '생활용품',
#   'category3': '생활잡화',
#   'category4': '신발관리도구'},
#  {'title': '포노포노러브 종이액자 10장 선물 가족사진 탁상 가벼운 정리 신혼 꾸미기 이벤트 기념일',
#   'link': 'https://search.shopping.naver.com/gate.nhn?id=83574747075',
#   'image': 'https://shopping-phinf.pstatic.net/main_8357474/83574747075.jpg',
#   'lprice': '6900',
#   'hprice': '',
#   'mallName': '포노포노러브',
#   'productId': '83574747075',
#   'productType': '2',
#   'brand': '',
#   'maker': '',
#   'category1': '가구/인테리어',
#   'category2': '인테리어소품',
#   'category3': '액자',
#   'category4': '퍼즐/그림/사진액자'},
#  {'title': '미드 센츄리 모던 포스터 캔버스 액자 18 몬드리안 구성B',
#   'link': 'https://search.shopping.naver.com/gate.nhn?id=83574746848',
#   'image': 'https://shopping-phinf.pstatic.net/main_8357474/83574746848.jpg',
#   'lprice': '6900',
#   'hprice': '',
#   'mallName': '세잔느화실',
#   'productId': '83574746848',
#   'productType': '2',
#   'brand': '',
#   'maker': '',
#   'category1': '가구/인테리어',
#   'category2': '인테리어소품',
#   'category3': '액자',
#   'category4': '퍼즐/그림/사진액자'},
#  {'title': '사과<b>그림</b> 액자 A3 2APP1 풍수<b>그림</b> 돈들어오는',
#   'link': 'https://search.shopping.naver.com/gate.nhn?id=83574746493',
#   'image': 'https://shopping-phinf.pstatic.net/main_8357474/83574746493.jpg',
#   'lprice': '48070',
#   'hprice': '',
#   'mallName': '파라다잇소',
#   'productId': '83574746493',
#   'productType': '2',
#   'brand': '',
#   'maker': '',
#   'category1': '가구/인테리어',
#   'category2': '인테리어소품',
#   'category3': '액자',
#   'category4': '벽걸이액자'},
#  {'title': '미드 센츄리 모던 포스터 캔버스 액자 19 몬드리안 구성C',
#   'link': 'https://search.shopping.naver.com/gate.nhn?id=83574745066',
#   'image': 'https://shopping-phinf.pstatic.net/main_8357474/83574745066.jpg',
#   'lprice': '6900',
#   'hprice': '',
#   'mallName': '세잔느화실',
#   'productId': '83574745066',
#   'productType': '2',
#   'brand': '',
#   'maker': '',
#   'category1': '가구/인테리어',
#   'category2': '인테리어소품',
#   'category3': '액자',
#   'category4': '퍼즐/그림/사진액자'},
#  {'title': '펜피아 2000 A4 <b>그림</b>일기 양면 낱권 초등 노트 공책 O',
#   'link': 'https://search.shopping.naver.com/gate.nhn?id=83574745041',
#   'image': 'https://shopping-phinf.pstatic.net/main_8357474/83574745041.jpg',
#   'lprice': '1180',
#   'hprice': '',
#   'mallName': '애니플',
#   'productId': '83574745041',
#   'productType': '2',
#   'brand': '펜피아',
#   'maker': '펜피아',
#   'category1': '생활/건강',
#   'category2': '문구/사무용품',
#   'category3': '노트/수첩',
#   'category4': '노트'},
#  {'title': '간밤의 아련함 1000조각 735 x 510mm',
#   'link': 'https://search.shopping.naver.com/gate.nhn?id=83574744190',
#   'image': 'https://shopping-phinf.pstatic.net/main_8357474/83574744190.jpg',
#   'lprice': '19970',
#   'hprice': '',
#   'mallName': '파라다잇소',
#   'productId': '83574744190',
#   'productType': '2',
#   'brand': '',
#   'maker': '',
#   'category1': '가구/인테리어',
#   'category2': '인테리어소품',
#   'category3': '액자',
#   'category4': '퍼즐/그림/사진액자'},
#  {'title': '<b>그림</b>이 그려진 복사 용지 가정 통신문에 사용',
#   'link': 'https://search.shopping.naver.com/gate.nhn?id=83574744001',
#   'image': 'https://shopping-phinf.pstatic.net/main_8357474/83574744001.jpg',
#   'lprice': '14970',
#   'hprice': '',
#   'mallName': '애니플',
#   'productId': '83574744001',
#   'productType': '2',
#   'brand': '',
#   'maker': '',
#   'category1': '생활/건강',
#   'category2': '문구/사무용품',
#   'category3': '용지',
#   'category4': '컬러복사지'},
#  {'title': '글쓰기 <b>그림</b> 드로잉 연습장 감성 일기장 프리 노트',
#   'link': 'https://search.shopping.naver.com/gate.nhn?id=83574743568',
#   'image': 'https://shopping-phinf.pstatic.net/main_8357474/83574743568.jpg',
#   'lprice': '1780',
#   'hprice': '',
#   'mallName': '애니플',
#   'productId': '83574743568',
#   'productType': '2',
#   'brand': '미소로',
#   'maker': '미소로',
#   'category1': '생활/건강',
#   'category2': '문구/사무용품',
#   'category3': '노트/수첩',
#   'category4': '노트'},
#  {'title': '목단 <b>그림</b> 액자 30W PEOVA10',
#   'link': 'https://search.shopping.naver.com/gate.nhn?id=83574743339',
#   'image': 'https://shopping-phinf.pstatic.net/main_8357474/83574743339.jpg',
#   'lprice': '39570',
#   'hprice': '',
#   'mallName': '파라다잇소',
#   'productId': '83574743339',
#   'productType': '2',
#   'brand': '',
#   'maker': '',
#   'category1': '가구/인테리어',
#   'category2': '인테리어소품',
#   'category3': '액자',
#   'category4': '벽걸이액자'},
#  {'title': '미드 센츄리 모던 포스터 캔버스 액자 20 몬드리안 구성D',
#   'link': 'https://search.shopping.naver.com/gate.nhn?id=83574742377',
#   'image': 'https://shopping-phinf.pstatic.net/main_8357474/83574742377.jpg',
#   'lprice': '6900',
#   'hprice': '',
#   'mallName': '세잔느화실',
#   'productId': '83574742377',
#   'productType': '2',
#   'brand': '',
#   'maker': '',
#   'category1': '가구/인테리어',
#   'category2': '인테리어소품',
#   'category3': '액자',
#   'category4': '퍼즐/그림/사진액자'},
#  {'title': 'Wellyu 중국어 선 입체 소나무 현관 장식 <b>그림</b> 사용자 정의 대형 벽화 녹색 벽지',
#   'link': 'https://search.shopping.naver.com/gate.nhn?id=83574742604',
#   'image': 'https://shopping-phinf.pstatic.net/main_8357474/83574742604.jpg',
#   'lprice': '47600',
#   'hprice': '',
#   'mallName': '더바른물건',
#   'productId': '83574742604',
#   'productType': '2',
#   'brand': '',
#   'maker': '',
#   'category1': '가구/인테리어',
#   'category2': 'DIY자재/용품',
#   'category3': '시트지',
#   'category4': '포인트시트지'},
#  {'title': '초등스프링<b>그림</b>일기 낱권 펜피아 색상랜덤 공책',
#   'link': 'https://search.shopping.naver.com/gate.nhn?id=83574742224',
#   'image': 'https://shopping-phinf.pstatic.net/main_8357474/83574742224.jpg',
#   'lprice': '990',
#   'hprice': '',
#   'mallName': '애니플',
#   'productId': '83574742224',
#   'productType': '2',
#   'brand': '',
#   'maker': '',
#   'category1': '생활/건강',
#   'category2': '문구/사무용품',
#   'category3': '노트/수첩',
#   'category4': '노트'},
#  {'title': '<b>그림</b>걸이 판천정고리 사이즈선택',
#   'link': 'https://search.shopping.naver.com/gate.nhn?id=83574739867',
#   'image': 'https://shopping-phinf.pstatic.net/main_8357473/83574739867.jpg',
#   'lprice': '3270',
#   'hprice': '',
#   'mallName': 'jungemall',
#   'productId': '83574739867',
#   'productType': '2',
#   'brand': '',
#   'maker': '',
#   'category1': '생활/건강',
#   'category2': '생활용품',
#   'category3': '생활잡화',
#   'category4': '신발관리도구'},
#  {'title': 'OH 명화유화그리기 A-056 아기고양이 중형 40x50',
#   'link': 'https://search.shopping.naver.com/gate.nhn?id=83574737739',
#   'image': 'https://shopping-phinf.pstatic.net/main_8357473/83574737739.jpg',
#   'lprice': '14270',
#   'hprice': '',
#   'mallName': '파라다잇소',
#   'productId': '83574737739',
#   'productType': '2',
#   'brand': '',
#   'maker': '',
#   'category1': '가구/인테리어',
#   'category2': '인테리어소품',
#   'category3': '액자',
#   'category4': '퍼즐/그림/사진액자'},
#  {'title': '미드 센츄리 모던 포스터 캔버스 액자 21 몬드리안 구성E',
#   'link': 'https://search.shopping.naver.com/gate.nhn?id=83574737480',
#   'image': 'https://shopping-phinf.pstatic.net/main_8357473/83574737480.jpg',
#   'lprice': '6900',
#   'hprice': '',
#   'mallName': '세잔느화실',
#   'productId': '83574737480',
#   'productType': '2',
#   'brand': '',
#   'maker': '',
#   'category1': '가구/인테리어',
#   'category2': '인테리어소품',
#   'category3': '액자',
#   'category4': '퍼즐/그림/사진액자'},
#  {'title': '데미안 헤르만 헤세 원작/조혜원 편/박승원 <b>그림</b>/방민호 감수',
#   'link': 'https://search.shopping.naver.com/gate.nhn?id=29781242620',
#   'image': 'https://shopping-phinf.pstatic.net/main_2978124/29781242620.20211121211545.jpg',
#   'lprice': '8550',
#   'hprice': '',
#   'mallName': '네이버',
#   'productId': '29781242620',
#   'productType': '1',
#   'brand': '',
#   'maker': '',
#   'category1': '도서',
#   'category2': '어린이',
#   'category3': '학습/학습만화',
#   'category4': ''},
#  {'title': '[이노플리아] 하이셀(몸과 마음을 치유하는 칼라파스 <b>그림</b>명상)',
#   'link': 'https://search.shopping.naver.com/gate.nhn?id=29781241618',
#   'image': 'https://shopping-phinf.pstatic.net/main_2978124/29781241618.20211121211543.jpg',
#   'lprice': '12600',
#   'hprice': '',
#   'mallName': '네이버',
#   'productId': '29781241618',
#   'productType': '1',
#   'brand': '',
#   'maker': '',
#   'category1': '도서',
#   'category2': '인문',
#   'category3': '인문일반',
#   'category4': '교양인문'},
#  {'title': '만화 <b>그림</b> 여성 속이 빈 Tshirt 스키니 가을 12731031S2764618181',
#   'link': 'https://search.shopping.naver.com/gate.nhn?id=29781223597',
#   'image': 'https://shopping-phinf.pstatic.net/main_2978122/29781223597.20211121211543.jpg',
#   'lprice': '26790',
#   'hprice': '',
#   'mallName': '네이버',
#   'productId': '29781223597',
#   'productType': '1',
#   'brand': '',
#   'maker': '',
#   'category1': '패션의류',
#   'category2': '여성의류',
#   'category3': '티셔츠',
#   'category4': ''}]

# %%
import os
import time
from PIL import Image

# 다운받을 이미지 url
# url = "https://dispatch.cdnser.be/cms-content/uploads/2020/04/09/a26f4b7b-9769-49dd-aed3-b7067fbc5a8c.jpg"

# time check
start = time.time()

# curl 요청
os.system("curl " + url + " > test.jpg")

# 이미지 다운로드 시간 체크
print(time.time() - start)

# 저장 된 이미지 확인
img = Image.open("test.jpg")
# Out:
# 0.11137557029724121

# %%
import os
len(os.listdir('./data/main_category3/'))
# Out:
# 102
